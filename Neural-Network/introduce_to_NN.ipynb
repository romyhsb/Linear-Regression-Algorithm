# %%
import pandas as pd 
import os
import tensorflow as tf 
from tensorflow.keras import  layers

# %%
os.getcwd()
os.chdir("c:/Users/Romi/Documents/project-linear-regression")

# %%
df = pd.read_csv("dataset\mushroom_cleaned.csv")
df.sample(5)
# Out:
#        cap-diameter  cap-shape  gill-attachment  ...  stem-color    season  class
# 41559           390          2                6  ...          11  0.888450      0
# 42154           129          6                0  ...           6  0.888450      1
# 29176           869          5                1  ...          11  0.943195      0
# 33909           423          6                6  ...           6  0.888450      0
# 26845           687          5                1  ...           3  0.943195      1
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54035 entries, 0 to 54034
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cap-diameter     54035 non-null  int64
#  1   cap-shape        54035 non-null  int64
#  2   gill-attachment  54035 non-null  int64
#  3   gill-color       54035 non-null  int64
#  4   stem-height      54035 non-null  float64
#  5   stem-width       54035 non-null  int64
#  6   stem-color       54035 non-null  int64
#  7   season           54035 non-null  float64
#  8   class            54035 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 3.7 MB

# %%
df.corr().round(2)
# Out:
#                  cap-diameter  cap-shape  ...  season  class
# cap-diameter             1.00       0.20  ...    0.11  -0.17
# cap-shape                0.20       1.00  ...    0.06  -0.13
# gill-attachment          0.20       0.04  ...   -0.04  -0.05
# gill-color               0.19       0.13  ...    0.06  -0.06
# stem-height              0.14      -0.01  ...   -0.00   0.18
# stem-width               0.83       0.22  ...    0.04  -0.18
# stem-color               0.12       0.03  ...    0.01  -0.13
# season                   0.11       0.06  ...    1.00  -0.08
# class                   -0.17      -0.13  ...   -0.08   1.00
#
# [9 rows x 9 columns]
